# %% [markdown]
# # Módulo 2: Preprocesamiento
#
# ## Expresiones regulares
#
#
# ### Actividad 1: En clase
# * Analizar información categórica.
# * Tomar las variables `beneficiarios_alimentos_dif_2014` y `observacion_mobiliario`. Analizarlas y extraer información usando expresiones regulares.
#
# ### Actividad 2: De tarea
#
# * Tomar las variables:
#     * `conectividad`.
#     * `observacion_pec2013`.
#     * `observacion_pec2014`.
# * Analizar **cuidadosamente** los patrones que se pueden obtener.
#     * Cuida que los patrones sean **todos** los posibles dentro de lo razonable, es decir, **información útil para diferenciar** a un centro educativo. Años, direcciones o cosas por el estilo no entran en esto.
# * Generar columnas nuevas con los patrones obtenidos del punto anterior.
#
# **Requerimiento especial: Instalar `unidecode`**

# %% [markdown]
# ## Expresiones regulares
#
# Las expresiones regulares son indicaciones con las que podemos extraer texto de cadenas basado en patrones. Tienen comandos específicos, nosotros las usaremos a través de la paquetería `re`.
#
# Si quieres obtener más información sobre los comandos utilizados u otros _hacks_ que puedes lograr usando esta herramienta, te recomiendo revisar: https://regexone.com/references/python.

# %%
import pandas as pd
import re
import unidecode
from matplotlib import pyplot as plt

plt.style.use('ggplot')

# %%
df = pd.read_csv('cleaned_inversiones2.csv',
                 index_col=0)

# %%
df.head()
# Out:
#    inmueble             municipio    clave_ct responsable     turno  \
# 0  1406848K  AHUALULCO DE MERCADO  14DPR0273Q           R  MATUTINO
# 1  1406850C  AHUALULCO DE MERCADO  14EPR0482V           R  MATUTINO
# 2  1406852K  AHUALULCO DE MERCADO  14EJN0200G           R  MATUTINO
# 3  1406854H  AHUALULCO DE MERCADO  14DJN0155L           R  MATUTINO
# 4  1406855A  AHUALULCO DE MERCADO  14EPR0014B           R  MATUTINO
#
#                nombre_ct                           director       nivel  \
# 0              5 DE MAYO     ANGELICA IVETT FLORES CARDENAS    PRIMARIA
# 1  VALENTIN GOMEZ FARIAS        MARIA EDITH CRUZ CASTAÃEDA    PRIMARIA
# 2        EMILIANO ZAPATA                  HILDA GARCIA VEGA  PREESCOLAR
# 3           JAVIER URIBE        MARIA ELENA ARELLANO NUÃEZ  PREESCOLAR
# 4        JOSE MA MERCADO  MARIA CONSEPCION PINZON RODRIGUEZ    PRIMARIA
#
#    matricula  docente  ...  inversion_programa_sana_2014  \
# 0        329       12  ...                           NaN
# 1         94        6  ...                           NaN
# 2        144        5  ...                           NaN
# 3        111        4  ...                           NaN
# 4        289       12  ...                           NaN
#
#    inversion_programa_coniba_2015  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#    inversion_escuelas_de_tiempo_completo_2015_(recurso_2014)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    inversion_programa_escuela_digna_2015  inversion_faeb_2015  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
#
#   inversion_fonden_2015  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#    inversion_infraestructura_educativa_estatal__2015_(recurso_2013)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    inversion_programa_escuelas_de_excelencia_2015_(recurso_2014)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    inversion_programa_sana_2015 otros_programas
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
#
# [5 rows x 55 columns]

# %%
df.describe(include=['object'])
# Out:
#         inmueble    municipio    clave_ct responsable     turno  \
# count       9489         9489        9489        9489      9489
# unique      7311          125        9191           2         5
# top     1408094X  GUADALAJARA  14EES0138D           R  MATUTINO
# freq           5          940           2        7311      7010
#
#             nombre_ct                       director     nivel  \
# count            9489                           9489      9489
# unique           2143                           8274         3
# top     BENITO JUAREZ  MA. CONCEPCION CAMPOS PERALTA  PRIMARIA
# freq              319                             12      4957
#
#               beneficiarios_alimentos_dif_2014  \
# count                                     4329
# unique                                     334
# top     BENEFICIARIOS = 10 / ALIMENTO CALIENTE
# freq                                       153
#
#                      aulas_interactivas_observacion  \
# count                                           525
# unique                                           39
# top     ESTADO = INSTALADO / AULAS INTERACTIVAS = 3
# freq                                             83
#
#                           aulas_provisionales_observacion  \
# count                                                 999
# unique                                                266
# top     TOTAL DE AULAS = 1/ POR SUSTITUIR USO EDUC = 1...
# freq                                                  187
#
#                        conectividad  \
# count                          6277
# unique                          186
# top     eJALISCO = 2 MB INSTALADO /
# freq                           1900
#
#                                       observacion_pec2013  \
# count                                                1986
# unique                                                496
# top     PEC XIII (2013 -2014) / APOYO TÃCNICO PEDAGÃ...
# freq                                                   19
#
#                                       observacion_pec2014  \
# count                                                2350
# unique                                                597
# top     PEC XIV (2014 - 2015) / APOYO TÃCNICO PEDAGÃ...
# freq                                                   25
#
#                         observacion_mobiliario
# count                                     2802
# unique                                    1739
# top     PIEZAS = 19 ALUMNOS =12 MATRICULA = 12
# freq                                        27

# %% [markdown]
# Podemos observar que hay un número aceptable de filas y además bastantes columnas, son tantas que ni siquiera se alcanzan a ver todas.
#
# Concentrémonos en las variables categóricas y de texto.

# %% [markdown]
# Vemos que hay diferentes cadenas de texto y eso que no estamos viendo el _big picture_ y solo vemos la moda.
#
#
# Dada la alta granularidad y el hecho de que son _ids_, descalificaremos desde un inicio _inmueble_ y _clave-ct_.
#
#
# Hagamos un análisis un poco más profundo.

# %% [markdown]
# Tomemos una variable sencilla y entendamos qué es lo que hay dentro: `turno`.

# %%
df['turno'].value_counts()
# Out:
# turno
# MATUTINO       7010
# VESPERTINO     2407
# NOCTURNO         50
# MIXTO            15
# DISCONTINUO       7
# Name: count, dtype: int64

# %% [markdown]
# Hay pocos valores únicos, ¿hay valores nulos?

# %%
df['turno'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No hay nulos. ¿Cómo se ven nuestros valores?

# %%
df.turno.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# En esta variable no parece que haya alguna peculiaridad interesante.
# ¿Qué pasa si vemos la de beneficiarios de alimentos?

# %%
df['beneficiarios_alimentos_dif_2014'].fillna('NA').value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Es un **desastre mayúsculo** pues hay demasiados valores únicos, 334 para ser exactos. Y la mayoría son nulos.
#
#
# Cambiemos el enfoque y generemos estas gráficas:
#
# * Variables con baja granularidad grafiquemos un pay.
# * Variables con alta granularidad grafiquemos un pay con aquellos que tienen mayor incidencia de aparición.

# %%
# Copia del frame
copy = df.select_dtypes(include=['object']).copy()

# Llenado de nulos temporalmente
copy.fillna('NA', inplace=True)

# %%
threshold = 10
seen_variables = []

for column in copy:
    value_counts = copy[column].value_counts(normalize=True)

    if len(value_counts) <= threshold:
        fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

        value_counts.plot(kind='bar', ax=ax1, alpha=0.4, color='blue')
        value_counts.plot(kind='pie', ax=ax2, autopct='%1.1f%%')

        seen_variables.append(column)
        fig.suptitle(f'Column: {column}')

# %% [markdown]
# Hay pocas variables que parece requieren poco (o nulo) tratamiento y de baja granularidad.
#
# Como casi siempre, el trabajo estará en las de mucha granularidad.
#
# Veamos algún ejemplo de las variables que caen en este caso.

# %%
missings = set(copy.columns.tolist()).difference(seen_variables)
missings = list(missings)
missings
# Out:
# ['clave_ct',
#  'nombre_ct',
#  'municipio',
#  'director',
#  'beneficiarios_alimentos_dif_2014',
#  'inmueble',
#  'aulas_provisionales_observacion',
#  'conectividad',
#  'observacion_mobiliario',
#  'observacion_pec2013',
#  'aulas_interactivas_observacion',
#  'observacion_pec2014']

# %% [markdown]
# Se observa entonces que hay espacios y caracteres especiales que deberán ser normalizados.
#
# La idea de normalizar los strings es que puede haber casos como el siguiente:
#
# * `'Raúl Romero'`.
# * `'Raul Romero'`.
#
# Ambos strings dicen y dan a entender lo mismo pero son diferentes, lo mismo ocurrirá si hay espacios o cosas por el estilo.

# %%
set(df['municipio'].apply(lambda x: unidecode.unidecode(x)).tolist())
# Out:
# {'ACATIC',
#  'ACATLAN DE JUAREZ',
#  'AHUALULCO DE MERCADO',
#  'AMACUECA',
#  'AMATITAN',
#  'AMECA',
#  'ARANDAS',
#  'ATEMAJAC DE BRIZUELA',
#  'ATENGO',
#  'ATENGUILLO',
#  'ATOTONILCO EL ALTO',
#  'ATOYAC',
#  'AUTLAN DE NAVARRO',
#  'AYOTLAN',
#  'AYUTLA',
#  'BOLAAOS',
#  'CAAADAS DE OBREGON',
#  'CABO CORRIENTES',
#  'CASIMIRO CASTILLO',
#  'CHAPALA',
#  'CHIMALTITAN',
#  'CHIQUILISTLAN',
#  'CIHUATLAN',
#  'COCULA',
#  'COLOTLAN',
#  'CONCEPCION DE BUENOS AIRES',
#  'CUAUTITLAN DE GARCIA BARRAGAN',
#  'CUAUTLA',
#  'CUQUIO',
#  'DEGOLLADO',
#  'EJUTLA',
#  'EL ARENAL',
#  'EL GRULLO',
#  'EL LIMON',
#  'EL SALTO',
#  'ENCARNACION DE DIAZ',
#  'ETZATLAN',
#  'GOMEZ FARIAS',
#  'GUACHINANGO',
#  'GUADALAJARA',
#  'HOSTOTIPAQUILLO',
#  'HUEJUCAR',
#  'HUEJUQUILLA EL ALTO',
#  'IXTLAHUACAN DE LOS MEMBRILLOS',
#  'IXTLAHUACAN DEL RIO',
#  'JALOSTOTITLAN',
#  'JAMAY',
#  'JESUS MARIA',
#  'JILOTLAN DE LOS DOLORES',
#  'JOCOTEPEC',
#  'JUANACATLAN',
#  'JUCHITLAN',
#  'LA BARCA',
#  'LA HUERTA',
#  'LA MANZANILLA DE LA PAZ',
#  'LAGOS DE MORENO',
#  'MAGDALENA',
#  'MASCOTA',
#  'MAZAMITLA',
#  'MEXTICACAN',
#  'MEZQUITIC',
#  'MIXTLAN',
#  'OCOTLAN',
#  'OJUELOS DE JALISCO',
#  'PIHUAMO',
#  'PONCITLAN',
#  'PUERTO VALLARTA',
#  'QUITUPAN',
#  'SAN CRISTOBAL DE LA BARRANCA',
#  'SAN DIEGO DE ALEJANDRIA',
#  'SAN GABRIEL',
#  'SAN IGNACIO CERRO GORDO',
#  'SAN JUAN DE LOS LAGOS',
#  'SAN JUANITO DE ESCOBEDO',
#  'SAN JULIAN',
#  'SAN MARCOS',
#  'SAN MARTIN DE BOLAAOS',
#  'SAN MARTIN HIDALGO',
#  'SAN MIGUEL EL ALTO',
#  'SAN PEDRO TLAQUEPAQUE',
#  'SAN SEBASTIAN DEL OESTE',
#  'SANTA MARIA DE LOS ANGELES',
#  'SANTA MARIA DEL ORO',
#  'SAYULA',
#  'TALA',
#  'TALPA DE ALLENDE',
#  'TAMAZULA DE GORDIANO',
#  'TAPALPA',
#  'TECALITLAN',
#  'TECHALUTA DE MONTENEGRO',
#  'TECOLOTLAN',
#  'TENAMAXTLAN',
#  'TEOCALTICHE',
#  'TEOCUITATLAN DE CORONA',
#  'TEPATITLAN DE MORELOS',
#  'TEQUILA',
#  'TEUCHITLAN',
#  'TIZAPAN EL ALTO',
#  'TLAJOMULCO DE ZUAIGA',
#  'TOLIMAN',
#  'TOMATLAN',
#  'TONALA',
#  'TONAYA',
#  'TONILA',
#  'TOTATICHE',
#  'TOTOTLAN',
#  'TUXCACUESCO',
#  'TUXCUECA',
#  'TUXPAN',
#  'UNION DE SAN ANTONIO',
#  'UNION DE TULA',
#  'VALLE DE GUADALUPE',
#  'VALLE DE JUAREZ',
#  'VILLA CORONA',
#  'VILLA GUERRERO',
#  'VILLA HIDALGO',
#  'VILLA PURIFICACION',
#  'YAHUALICA DE GONZALEZ GALLO',
#  'ZACOALCO DE TORRES',
#  'ZAPOPAN',
#  'ZAPOTILTIC',
#  'ZAPOTITLAN DE VADILLO',
#  'ZAPOTLAN DEL REY',
#  'ZAPOTLAN EL GRANDE',
#  'ZAPOTLANEJO'}

# %% [markdown]
# Generalicemos este procedimiento creando una función que nos permita estandarizar texto.

# %%
def text_treatment(text):
    """Basic text treatment function
    
    Parameters
    ----------
    text: str
        String to be normalized.

    Returns
    -------
    new_text: str
        Normalized text. 
        No extra spaces, normal spaces turned to underscores 
        and no accents.
    
    """
    new_text = unidecode.unidecode(text.strip().replace(' ', '_'))

    return new_text

# %%
# Aplicando código
for column in copy:
    copy[column] = copy[column].apply(lambda x: text_treatment(x))

# %%
copy.head()
# Out:
#    inmueble             municipio    clave_ct responsable     turno  \
# 0  1406848K  AHUALULCO_DE_MERCADO  14DPR0273Q           R  MATUTINO
# 1  1406850C  AHUALULCO_DE_MERCADO  14EPR0482V           R  MATUTINO
# 2  1406852K  AHUALULCO_DE_MERCADO  14EJN0200G           R  MATUTINO
# 3  1406854H  AHUALULCO_DE_MERCADO  14DJN0155L           R  MATUTINO
# 4  1406855A  AHUALULCO_DE_MERCADO  14EPR0014B           R  MATUTINO
#
#                nombre_ct                           director       nivel  \
# 0              5_DE_MAYO     ANGELICA_IVETT_FLORES_CARDENAS    PRIMARIA
# 1  VALENTIN_GOMEZ_FARIAS         MARIA_EDITH_CRUZ_CASTAAEDA    PRIMARIA
# 2        EMILIANO_ZAPATA                  HILDA_GARCIA_VEGA  PREESCOLAR
# 3           JAVIER_URIBE         MARIA_ELENA_ARELLANO_NUAEZ  PREESCOLAR
# 4        JOSE_MA_MERCADO  MARIA_CONSEPCION_PINZON_RODRIGUEZ    PRIMARIA
#
#          beneficiarios_alimentos_dif_2014 aulas_interactivas_observacion  \
# 0  BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE                             NA
# 1  BENEFICIARIOS_=_30_/_ALIMENTO_CALIENTE                             NA
# 2      BENEFICIARIOS_=_20_/_ALIMENTO_FRIO                             NA
# 3  BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE                             NA
# 4  BENEFICIARIOS_=_40_/_ALIMENTO_CALIENTE                             NA
#
#   aulas_provisionales_observacion  \
# 0                              NA
# 1                              NA
# 2                              NA
# 3                              NA
# 4                              NA
#
#                                        conectividad  \
# 0                       eJALISCO_=_2_MB_INSTALADO_/
# 1  eJALISCO_=_2_MB_INSTALADO_/INTERNET_PARTICULAR_/
# 2  eJALISCO_=_2_MB_INSTALADO_/INTERNET_PARTICULAR_/
# 3                       eJALISCO_=_2_MB_INSTALADO_/
# 4  eJALISCO_=_2_MB_INSTALADO_/INTERNET_PARTICULAR_/
#
#                                  observacion_pec2013  \
# 0                                                 NA
# 1  PEC_XIII_(2013_-2014)_/_APOYO_TACNICO_PEDAGAGI...
# 2  PEC_XIII_(2013_-2014)_/_APOYO_TACNICO_PEDAGAGI...
# 3                                                 NA
# 4                                                 NA
#
#                                  observacion_pec2014  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                                 NA
# 4  PEC_XIV_(2014_-_2015)_/_APOYO_TACNICO_PEDAGAGI...
#
#                       observacion_mobiliario
# 0  PIEZAS_=_569_ALUMNOS_=304_MATRICULA_=_304
# 1    PIEZAS_=_179_ALUMNOS_=93_MATRICULA_=_93
# 2  PIEZAS_=_204_ALUMNOS_=142_MATRICULA_=_142
# 3  PIEZAS_=_168_ALUMNOS_=117_MATRICULA_=_117
# 4  PIEZAS_=_518_ALUMNOS_=276_MATRICULA_=_344

# %% [markdown]
# Comparemos cambios que hayan existido entre las variables normalizadas y las variables originales.

# %%
for column in copy:
    treated_uniques = copy[column].nunique()

    original_uniques = df[column].nunique()

    message = f'Column: {column}. Originals: {original_uniques}. Treated: {treated_uniques} \n'
    
    print(message)
# Out:
# Column: inmueble. Originals: 7311. Treated: 7311
#
# Column: municipio. Originals: 125. Treated: 125
#
# Column: clave_ct. Originals: 9191. Treated: 9191
#
# Column: responsable. Originals: 2. Treated: 2
#
# Column: turno. Originals: 5. Treated: 5
#
# Column: nombre_ct. Originals: 2143. Treated: 2143
#
# Column: director. Originals: 8274. Treated: 8274
#
# Column: nivel. Originals: 3. Treated: 3
#
# Column: beneficiarios_alimentos_dif_2014. Originals: 334. Treated: 335
#
# Column: aulas_interactivas_observacion. Originals: 39. Treated: 40
#
# Column: aulas_provisionales_observacion. Originals: 266. Treated: 267
#
# Column: conectividad. Originals: 186. Treated: 187
#
# Column: observacion_pec2013. Originals: 496. Treated: 497
#
# Column: observacion_pec2014. Originals: 597. Treated: 598
#
# Column: observacion_mobiliario. Originals: 1739. Treated: 1740

# %% [markdown]
# El resultado es igual.
# ![image.png](attachment:image.png)
#
# De antemano era muy poco manejable ver todas los valores de todas las columnas, así que aunque el procedimiento haya sido "en vano" para este caso particular, es importante buscar estandarizar textos para no perder información o asumir que una información es diferente a otra solo por _typos_.
#
#
# #### Análisis de información "oculta"
#
# Observamos que hay ciertas columnas con información "oculta", como:
#
# * `beneficiarios_alimentos_dif_2014`.
# * `conectividad	`.
# * `observacion_pec2013`.
# * `observacion_pec2014`.
# * `observacion_mobiliario`.
#
# Antes de empezar a extraer posible información, veamos algunas de las variables que aparentan tener solo `None`.

# %% [markdown]
# Se observa que, así como en las variables anteriormente mencionadas tenemos un área de oportunidad de información embebida en texto.

# %%
variables = ['aulas_interactivas_observacion',
             'aulas_provisionales_observacion',
             'beneficiarios_alimentos_dif_2014',
             'conectividad',
             'observacion_pec2013',
             'observacion_pec2014',
             'observacion_mobiliario'
            ]

# %% [markdown]
# #### RegEx
#
# Las expresiones regulares son una de las herramientas que nos ayudarán a extraer texto.
#
# Son cadenas de texto que a su vez dan indicaciones para poder extraer información específica según sea el caso que nos interese.
#
#
# Suponga el siguiente ejemplo:
#
# cadena = `'Hola, soy Raúl y tengo 26 años'`
#
# Si usted busca extraer la edad de la persona, la respuesta sería el siguiente código:
#
# ```
# regex = r'\d+'
# result = re.findall(regex, cadena)
#
# ```
#
# Con el siguiente output:
#
# ```
# ['26']
# ```
#
# Veamos:

# %%
cadena = 'Hola, soy Raúl y tengo 26 años'

regex = r'\d'

result = re.findall(regex, cadena)

result
# Out:
# ['2', '6']

# %% [markdown]
# Vemos varios componentes aquí:
# * `cadena`. Esto es simplemente un string sobre el cual buscaremos patrón.
# * `regex`. Es una variable con una expresión regular. Las expresiones regulares se caracterian por tener una `r` antes de la primer comilla. En realidad no hay problema si no se agrega pero puede ayudar sobre todo cuando hay espacios o cosas por el estilo.
# * `re`. Paquetería que nos permite implementar regex.
# * `findall`. Es una de las muchas implementaciones, ésta nos permite buscar todos los elementos.
#
#
#
# Apliquemos el caso a algunas de las columnas que tenemos.
#
#
# #### Beneficiarios alimentos DIF 2014

# %%
variable = 'beneficiarios_alimentos_dif_2014'

# %%
copy[variable].unique()
# Out:
# array(['BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_30_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_20_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_40_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_30_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_50_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_100_/_ALIMENTO_CALIENTE', 'NA',
#        'BENEFICIARIOS_=_60_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_10_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_20_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_15_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_5_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_75_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_80_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_65_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_170_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_160_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_25_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_120_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_35_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_105_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_33_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_51_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_17_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_58_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_39_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_66_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_190_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_14_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_44_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_11_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_42_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_13_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_12_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_126_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_29_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_27_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_16_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_31_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_36_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_18_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_46_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_19_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_59_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_8_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_22_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_9_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_28_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_44_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_104_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_135_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_116_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_164_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_32_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_132_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_67_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_93_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_49_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_83_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_53_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_55_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_6_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_4_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_18_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_9_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_62_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_55_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_92_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_48_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_19_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_10_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_13_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_5_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_15_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_14_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_6_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_8_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_16_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_32_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_11_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_17_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_7_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_103_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_90_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_35_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_41_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_26_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_23_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_37_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_40_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_70_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_110_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_47_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_12_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_4_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_50_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_45_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_24_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_43_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_2_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_23_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_146_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_102_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_86_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_80_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_115_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_79_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_61_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_147_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_25_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_7_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_41_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_36_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_22_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_24_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_43_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_57_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_130_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_76_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_1_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_29_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_3_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_37_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_68_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_2_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_97_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_57_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_73_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_34_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_38_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_52_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_46_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_123_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_86_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_54_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_115_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_91_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_28_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_31_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_26_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_125_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_81_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_63_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_21_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_3_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_64_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_140_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_78_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_236_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_241_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_364_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_52_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_62_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_112_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_100_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_82_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_143_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_104_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_131_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_175_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_91_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_82_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_21_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_85_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_75_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_38_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_45_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_33_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_81_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_95_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_49_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_27_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_114_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_48_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_183_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_236_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_47_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_66_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_77_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_255_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_72_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_90_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_74_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_65_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_79_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_71_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_56_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_69_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_112_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_235_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_68_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_150_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_156_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_148_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_96_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_110_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_108_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_89_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_153_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_154_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_85_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_105_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_220_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_126_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_135_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_42_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_122_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_107_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_87_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_172_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_300_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_98_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_94_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_83_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_70_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_144_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_129_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_151_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_116_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_131_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_61_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_51_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_197_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_118_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_101_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_93_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_123_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_67_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_39_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_280_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_139_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_92_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_147_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_58_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_137_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_145_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_152_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_108_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_103_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_129_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_84_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_98_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_54_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_63_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_59_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_225_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_71_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_76_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_101_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_34_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_165_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_200_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_182_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_106_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_184_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_158_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_124_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_88_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_240_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_160_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_190_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_138_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_132_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_196_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_238_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_226_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_210_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_150_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_157_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_186_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_120_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_136_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_176_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_168_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_220_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_64_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_152_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_435_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_205_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_155_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_140_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_106_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_133_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_72_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_53_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_136_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_69_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_128_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_78_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_196_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_56_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_157_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_168_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_176_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_143_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_122_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_74_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_166_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_89_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_99_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_102_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_212_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_73_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_99_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_139_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_134_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_96_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_87_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_77_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_119_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_325_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_200_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_107_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_161_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_185_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_94_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_179_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_128_/_ALIMENTO_FRIO',
#        'BENEFICIARIOS_=_149_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_88_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_194_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_192_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_113_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_84_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_1_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_172_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_111_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_124_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_227_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_305_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_208_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_169_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_109_/_ALIMENTO_CALIENTE',
#        'BENEFICIARIOS_=_138_/_ALIMENTO_CALIENTE'], dtype=object)

# %% [markdown]
# ¿Qué tenemos en común?
#
# * Cantidad de beneficiarios.
# * Tipo de alimento.
#
#
# ##### Primer caso:

# %%
# String de ejemplo
string = 'BENEFICIARIOS_=_50_/_ALIMENTO_FRIO'

# %%
regex = r'\d+'

# %% [markdown]
# Componentes:
# * `\d`: Extrae dígitos.
# * `+`: Uno o más ocurrencias.

# %%
result = re.findall(regex, string)
result
# Out:
# ['50']

# %%
# Convirtiendo a número:
result = sum([int(c) for c in result])

# %% [markdown]
# ##### Segundo caso:

# %%
regex = r'(FRIO|CALIENTE)'

# %% [markdown]
# Componentes:
# * `()`: El uso de paréntesis extrae subgrupos.
# * `|`: Operador lógico `OR`.

# %%
result = re.findall(regex, string)
result[0]
# Out:
# 'FRIO'

# %% [markdown]
# Teniendo esto en mente podemos aplicar la función y tener **dos nuevos _features_**.

# %%
copy[variable + '_beneficiarios'] = copy[variable].apply(
    lambda x: sum(int(c) for c in re.findall(r'\d+', x))
)

# %%
copy[[variable, variable + '_beneficiarios']]
# Out:
#             beneficiarios_alimentos_dif_2014  \
# 0     BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE
# 1     BENEFICIARIOS_=_30_/_ALIMENTO_CALIENTE
# 2         BENEFICIARIOS_=_20_/_ALIMENTO_FRIO
# 3     BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE
# 4     BENEFICIARIOS_=_40_/_ALIMENTO_CALIENTE
# ...                                      ...
# 9484                                      NA
# 9485                                      NA
# 9486      BENEFICIARIOS_=_50_/_ALIMENTO_FRIO
# 9487                                      NA
# 9488                                      NA
#
#       beneficiarios_alimentos_dif_2014_beneficiarios
# 0                                                 60
# 1                                                 30
# 2                                                 20
# 3                                                 60
# 4                                                 40
# ...                                              ...
# 9484                                               0
# 9485                                               0
# 9486                                              50
# 9487                                               0
# 9488                                               0
#
# [9489 rows x 2 columns]

# %% [markdown]
# Observamos un detalle, los datos con `NA` los hizo transformó en cero porque no hay coincidencia, entonces es una lista vacía que evidentemente suma cero.
#
# Esto no es del todo correcto, corrijamos pero ahora de una manera más entendible.

# %%
def regex_beneficiarios(string, na_string='NA'):
    if string is None or string == na_string:
        return na_string
    regex = r'\d+'

    return sum([int(c) for c in re.findall(regex, string)])

# %%
copy[variable + '_beneficiarios'] = copy[variable].apply(regex_beneficiarios)

# %%
copy[[variable, variable + '_beneficiarios']]
# Out:
#             beneficiarios_alimentos_dif_2014  \
# 0     BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE
# 1     BENEFICIARIOS_=_30_/_ALIMENTO_CALIENTE
# 2         BENEFICIARIOS_=_20_/_ALIMENTO_FRIO
# 3     BENEFICIARIOS_=_60_/_ALIMENTO_CALIENTE
# 4     BENEFICIARIOS_=_40_/_ALIMENTO_CALIENTE
# ...                                      ...
# 9484                                      NA
# 9485                                      NA
# 9486      BENEFICIARIOS_=_50_/_ALIMENTO_FRIO
# 9487                                      NA
# 9488                                      NA
#
#      beneficiarios_alimentos_dif_2014_beneficiarios
# 0                                                60
# 1                                                30
# 2                                                20
# 3                                                60
# 4                                                40
# ...                                             ...
# 9484                                             NA
# 9485                                             NA
# 9486                                             50
# 9487                                             NA
# 9488                                             NA
#
# [9489 rows x 2 columns]

# %% [markdown]
# #### Observación mobiliario

# %%
variable = 'observacion_mobiliario'

# %%
copy[variable].unique()
# Out:
# array(['PIEZAS_=_569_ALUMNOS_=304_MATRICULA_=_304',
#        'PIEZAS_=_179_ALUMNOS_=93_MATRICULA_=_93',
#        'PIEZAS_=_204_ALUMNOS_=142_MATRICULA_=_142', ...,
#        'PIEZAS_=_351_ALUMNOS_=327_MATRICULA_=_327',
#        'PIEZAS_=_114_ALUMNOS_=105_MATRICULA_=_105',
#        'PIEZAS_=_132_ALUMNOS_=92_MATRICULA_=_154'], dtype=object)

# %% [markdown]
# Hay 3 componentes principales:
# * Piezas.
# * Alumnos (que por alguna razón son considerados "mobiliario" wtf).
# * Matrícula.

# %%
string = 'PIEZAS_=_569_ALUMNOS_=304_MATRICULA_=_604'

# %%
re.findall('\d+', string)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\4054500112.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall('\d+', string)
# ['569', '304', '604']

# %% [markdown]
# Si le lanzamos un `d+` nos va a traer los 3 y nos arriesgamos a que vengan en desorden los textos.

# %%
texto_especial = 'MATRICULA'
regex = f'{texto_especial}\D+(\d+)'
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2783606171.py:2: SyntaxWarning: invalid escape sequence '\D'
#   regex = f'{texto_especial}\D+(\d+)'

# %%
re.findall(regex, string)
# Out:
# ['604']

# %% [markdown]
# Componentes:
# * `\D`: Extrae todo caracter que **no** es un número.
# * `()`: El uso de paréntesis extrae subgrupos.
# * `+`: Uno o más ocurrencias.
#
#
# Generemos una función.

# %%
def regex_mobiliario(string: str, special_text: str, na_string: str = 'NA') -> int:
    if string is None or string == na_string:
        return na_string
    regex = f'{special_text}\D+(\d+)'

    return sum([int (c) for c in re.findall(regex, string)])
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\3659879852.py:4: SyntaxWarning: invalid escape sequence '\D'
#   regex = f'{special_text}\D+(\d+)'

# %%
special_texts = ['PIEZAS', 'ALUMNOS', 'MATRICULA']

new_variables = []

for special_text in special_texts:
    new_variable = f'{variable}_{special_text}'.lower()

    copy[new_variable] = copy[variable].apply(
    lambda x: regex_mobiliario(x, special_text)
    )
    new_variables.append(new_variable)

# %%
copy[[variable] + new_variables]
# Out:
#                          observacion_mobiliario observacion_mobiliario_piezas  \
# 0     PIEZAS_=_569_ALUMNOS_=304_MATRICULA_=_304                           569
# 1       PIEZAS_=_179_ALUMNOS_=93_MATRICULA_=_93                           179
# 2     PIEZAS_=_204_ALUMNOS_=142_MATRICULA_=_142                           204
# 3     PIEZAS_=_168_ALUMNOS_=117_MATRICULA_=_117                           168
# 4     PIEZAS_=_518_ALUMNOS_=276_MATRICULA_=_344                           518
# ...                                         ...                           ...
# 9484                                         NA                            NA
# 9485                                         NA                            NA
# 9486                                         NA                            NA
# 9487                                         NA                            NA
# 9488                                         NA                            NA
#
#      observacion_mobiliario_alumnos observacion_mobiliario_matricula
# 0                               304                              304
# 1                                93                               93
# 2                               142                              142
# 3                               117                              117
# 4                               276                              344
# ...                             ...                              ...
# 9484                             NA                               NA
# 9485                             NA                               NA
# 9486                             NA                               NA
# 9487                             NA                               NA
# 9488                             NA                               NA
#
# [9489 rows x 4 columns]

# %% [markdown]
# ##### Algunos otros hacks útiles en RegEx
#
# * `.`: Cualquier caracter. Útil, pero peligroso porque se puede escapar todo.
# * `\s`: Cualquier espacio en blanco.
# * `\S`: Cualquier espacio que no sea blanco.
# * `[a-z]`: Caracteres de la "a" a la "z".
# * `[0-9]`: Caracteres del 0 al 9.
# * `\w`: Cualquier caracter alfanumérico.
# * `\W`: Cualquier caracter no alfanumérico.
# * `*`: Cero o más repeticiones.

# %%
# Count de fuentes de conectividad
def count_sources(connectivity):
    if pd.isna(connectivity):
        return 0
    return connectivity.count("/") + 1 

# Sacar ancho de banda total
def sum_bandwidth(connectivity):
    if pd.isna(connectivity):
        return 0
    mb_values = re.findall(r"(\d+)\s*MB", connectivity)  # Buscar valores en MB
    return sum(map(int, mb_values)) if mb_values else 0

# Bool internet particular
def has_private_internet(connectivity):
    if pd.isna(connectivity):
        return 0
    return int("INTERNET PARTICULAR" in connectivity)

# Count de beneficiados del PEC
def extract_beneficiaries(observation):
    if pd.isna(observation):
        return 0
    match = re.search(r"BENEFICIADOS=(\d+)", observation)
    return int(match.group(1)) if match else 0

# %%
def procesar_datos(csv_file_path):
    df = pd.read_csv(csv_file_path)

    cols = ["conectividad", "observacion_pec2013", "observacion_pec2014"]
    
    df_selected = df[cols]


    df_selected["num_fuentes_conectividad"] = df_selected["conectividad"].apply(count_sources)
    df_selected["ancho_banda_total_mb"] = df_selected["conectividad"].apply(sum_bandwidth)
    df_selected["internet_particular"] = df_selected["conectividad"].apply(has_private_internet)
    df_selected["beneficiados_pec2013"] = df_selected["observacion_pec2013"].apply(extract_beneficiaries)
    df_selected["beneficiados_pec2014"] = df_selected["observacion_pec2014"].apply(extract_beneficiaries)

    output_file = "RegEx.csv"
    df_selected.to_csv(output_file, index=False)
    df_selected

# %%
csv_file_path = "cleaned_inversiones2.csv"
procesar_datos(csv_file_path)
# Out:
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2136083540.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["num_fuentes_conectividad"] = df_selected["conectividad"].apply(count_sources)
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2136083540.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["ancho_banda_total_mb"] = df_selected["conectividad"].apply(sum_bandwidth)
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2136083540.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["internet_particular"] = df_selected["conectividad"].apply(has_private_internet)
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2136083540.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["beneficiados_pec2013"] = df_selected["observacion_pec2013"].apply(extract_beneficiaries)
# C:\Users\hecto\AppData\Local\Temp\ipykernel_8040\2136083540.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["beneficiados_pec2014"] = df_selected["observacion_pec2014"].apply(extract_beneficiaries)

# %% [markdown]
# ## ¿Qué harías para detectar todos los patrones a extraer con expresiones regulares?
#
#     - Explorar valores únicos en cada columna para identificar estructuras repetitivas.
#     - Definir expresiones regulares específicas para cada patrón.
#     - Usar `re.findall()` o `re.search()` para extraer la información relevante.
#     - Transformar los datos en nuevas variables numéricas o categóricas.
#
# ## ¿Cuál es la ventaja de extraer información embebida en textos?
#
#     - Permite estructurar datos no estructurados.
#     - Proporciona mayor granularidad en el análisis.
#     - Facilita la toma de decisiones basada en datos organizados.
#     - Automatiza el procesamiento de grandes volúmenes de datos.
